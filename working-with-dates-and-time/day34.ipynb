# %%
import numpy as np
import pandas as pd

# %%
date=pd.read_csv('orders.csv')

time=pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
#convertin to datetime datatype
date['date']=pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
#Extract yaer
date['date_year']=date['date'].dt.year
date.sample(5)
# Out:
#           date  product_id  city_id  orders  date_year
# 999 2019-10-15        6371        7      22       2019
# 240 2019-08-09        4938       28       2       2019
# 797 2019-03-17        4392       26       8       2019
# 441 2019-02-15        2906       16       2       2019
# 804 2018-10-03        3691       17       1       2018

# %%
#Extract Month
date['date_month_no']=date['date'].dt.month
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1

# %%
date['date_month_name']=date['date'].dt.month_name
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#                                      date_month_name
# 0  <bound method PandasDelegate._add_delegate_acc...
# 1  <bound method PandasDelegate._add_delegate_acc...
# 2  <bound method PandasDelegate._add_delegate_acc...
# 3  <bound method PandasDelegate._add_delegate_acc...
# 4  <bound method PandasDelegate._add_delegate_acc...

# %%
#Extract Days
date['date_day']=date['date'].dt.day
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#                                      date_month_name  date_day
# 0  <bound method PandasDelegate._add_delegate_acc...        10
# 1  <bound method PandasDelegate._add_delegate_acc...        15
# 2  <bound method PandasDelegate._add_delegate_acc...        23
# 3  <bound method PandasDelegate._add_delegate_acc...        17
# 4  <bound method PandasDelegate._add_delegate_acc...         6

# %%
#day of week
date['date_dow']=date['date'].dt.dayofweek
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#                                      date_month_name  date_day  date_dow
# 0  <bound method PandasDelegate._add_delegate_acc...        10         1
# 1  <bound method PandasDelegate._add_delegate_acc...        15         2
# 2  <bound method PandasDelegate._add_delegate_acc...        23         1
# 3  <bound method PandasDelegate._add_delegate_acc...        17         5
# 4  <bound method PandasDelegate._add_delegate_acc...         6         6

# %%
#day of week -name
date['date_dow_name']=date['date'].dt.day_name
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no  \
# 0 2019-12-10       2019             12
# 1 2018-08-15       2018              8
# 2 2018-10-23       2018             10
# 3 2019-08-17       2019              8
# 4 2019-01-06       2019              1
#
#                                      date_month_name  date_day  date_dow  \
# 0  <bound method PandasDelegate._add_delegate_acc...        10         1
# 1  <bound method PandasDelegate._add_delegate_acc...        15         2
# 2  <bound method PandasDelegate._add_delegate_acc...        23         1
# 3  <bound method PandasDelegate._add_delegate_acc...        17         5
# 4  <bound method PandasDelegate._add_delegate_acc...         6         6
#
#                                        date_dow_name
# 0  <bound method PandasDelegate._add_delegate_acc...
# 1  <bound method PandasDelegate._add_delegate_acc...
# 2  <bound method PandasDelegate._add_delegate_acc...
# 3  <bound method PandasDelegate._add_delegate_acc...
# 4  <bound method PandasDelegate._add_delegate_acc...

# %%
# is weekend
date['date_is_weekend']=np.where(date['date_dow_name'].isin(['Sunday','Saturday']),1,0)
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no  \
# 0 2019-12-10       2019             12
# 1 2018-08-15       2018              8
# 2 2018-10-23       2018             10
# 3 2019-08-17       2019              8
# 4 2019-01-06       2019              1
#
#                                      date_month_name  date_day  date_dow  \
# 0  <bound method PandasDelegate._add_delegate_acc...        10         1
# 1  <bound method PandasDelegate._add_delegate_acc...        15         2
# 2  <bound method PandasDelegate._add_delegate_acc...        23         1
# 3  <bound method PandasDelegate._add_delegate_acc...        17         5
# 4  <bound method PandasDelegate._add_delegate_acc...         6         6
#
#                                        date_dow_name  date_is_weekend
# 0  <bound method PandasDelegate._add_delegate_acc...                0
# 1  <bound method PandasDelegate._add_delegate_acc...                0
# 2  <bound method PandasDelegate._add_delegate_acc...                0
# 3  <bound method PandasDelegate._add_delegate_acc...                0
# 4  <bound method PandasDelegate._add_delegate_acc...                0

# %%
#Extract week of year
date['date_week']=date['date'].dt.week
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-c777743ce744> in <cell line: 2>()
#       1 #Extract week of year
# ----> 2 date['date_week']=date['date'].dt.week
#       3 date.drop(columns=['product_id','city_id','orders']).head()
#
# AttributeError: 'DatetimeProperties' object has no attribute 'week'

# %%
#Extract Quarter
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no  \
# 0 2019-12-10       2019             12
# 1 2018-08-15       2018              8
# 2 2018-10-23       2018             10
# 3 2019-08-17       2019              8
# 4 2019-01-06       2019              1
#
#                                      date_month_name  date_day  date_dow  \
# 0  <bound method PandasDelegate._add_delegate_acc...        10         1
# 1  <bound method PandasDelegate._add_delegate_acc...        15         2
# 2  <bound method PandasDelegate._add_delegate_acc...        23         1
# 3  <bound method PandasDelegate._add_delegate_acc...        17         5
# 4  <bound method PandasDelegate._add_delegate_acc...         6         6
#
#                                        date_dow_name  date_is_weekend  quarter
# 0  <bound method PandasDelegate._add_delegate_acc...                0        4
# 1  <bound method PandasDelegate._add_delegate_acc...                0        3
# 2  <bound method PandasDelegate._add_delegate_acc...                0        4
# 3  <bound method PandasDelegate._add_delegate_acc...                0        3
# 4  <bound method PandasDelegate._add_delegate_acc...                0        1

# %%
#Extract Semester
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no  \
# 0 2019-12-10       2019             12
# 1 2018-08-15       2018              8
# 2 2018-10-23       2018             10
# 3 2019-08-17       2019              8
# 4 2019-01-06       2019              1
#
#                                      date_month_name  date_day  date_dow  \
# 0  <bound method PandasDelegate._add_delegate_acc...        10         1
# 1  <bound method PandasDelegate._add_delegate_acc...        15         2
# 2  <bound method PandasDelegate._add_delegate_acc...        23         1
# 3  <bound method PandasDelegate._add_delegate_acc...        17         5
# 4  <bound method PandasDelegate._add_delegate_acc...         6         6
#
#                                        date_dow_name  date_is_weekend  \
# 0  <bound method PandasDelegate._add_delegate_acc...                0
# 1  <bound method PandasDelegate._add_delegate_acc...                0
# 2  <bound method PandasDelegate._add_delegate_acc...                0
# 3  <bound method PandasDelegate._add_delegate_acc...                0
# 4  <bound method PandasDelegate._add_delegate_acc...                0
#
#    quarter  semester
# 0        4         2
# 1        3         2
# 2        4         2
# 3        3         2
# 4        1         1

# %%
#Extract Time elapsed between dates
import datetime

today = datetime.datetime.today()

today
# Out:
# datetime.datetime(2024, 6, 27, 3, 2, 52, 816697)

# %%
today - date['date']
# Out:
# 0     1661 days 03:02:52.816697
# 1     2143 days 03:02:52.816697
# 2     2074 days 03:02:52.816697
# 3     1776 days 03:02:52.816697
# 4     1999 days 03:02:52.816697
#                  ...
# 995   2089 days 03:02:52.816697
# 996   2030 days 03:02:52.816697
# 997   1878 days 03:02:52.816697
# 998   1943 days 03:02:52.816697
# 999   1717 days 03:02:52.816697
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - date['date']).dt.days
# Out:
# 0      1661
# 1      2143
# 2      2074
# 3      1776
# 4      1999
#        ...
# 995    2089
# 996    2030
# 997    1878
# 998    1943
# 999    1717
# Name: date, Length: 1000, dtype: int64

# %%
np.round((today -date['date']) / np.timedelta64(1, 'M'),0)
# Out:
# 0      54.0
# 1      69.0
# 2      67.0
# 3      57.0
# 4      64.0
#        ...
# 995    67.0
# 996    65.0
# 997    61.0
# 998    63.0
# 999    55.0
# Name: date, Length: 1000, dtype: float64

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
# Converting to datetime datatype
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec
# 0     0   50    0
# 1    23   40    0
# 2     0   21    0
# 3     0   31    0
# 4    23   11    0

# %%
#Extract Time part
time['time'] = time['date'].dt.time

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %%
#Time difference
today - time['date']
# Out:
# 0     3847 days 02:12:52.816697
# 1     3711 days 03:22:52.816697
# 2     4197 days 02:41:52.816697
# 3     3499 days 02:31:52.816697
# 4     3896 days 03:51:52.816697
#                  ...
# 995   4486 days 02:12:52.816697
# 996   3807 days 03:48:52.816697
# 997   4272 days 03:25:52.816697
# 998   4388 days 03:28:52.816697
# 999   3660 days 03:37:52.816697
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.323888e+08
# 1      3.206426e+08
# 2      3.626305e+08
# 3      3.023227e+08
# 4      3.366283e+08
#            ...
# 995    3.875984e+08
# 996    3.289385e+08
# 997    3.691132e+08
# 998    3.791357e+08
# 999    3.162371e+08
# Name: date, Length: 1000, dtype: float64

# %%
# in minutes

(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      5.539813e+06
# 1      5.344043e+06
# 2      6.043842e+06
# 3      5.038712e+06
# 4      5.610472e+06
#            ...
# 995    6.459973e+06
# 996    5.482309e+06
# 997    6.151886e+06
# 998    6.318929e+06
# 999    5.270618e+06
# Name: date, Length: 1000, dtype: float64

# %%
# in hours

(today - time['date'])/np.timedelta64(1,'h')
# Out:
# 0       92330.214671
# 1       89067.381338
# 2      100730.698005
# 3       83978.531338
# 4       93507.864671
#            ...
# 995    107666.214671
# 996     91371.814671
# 997    102531.431338
# 998    105315.481338
# 999     87843.631338
# Name: date, Length: 1000, dtype: float64
